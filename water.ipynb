# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
urlread = 'https://www.water.gov.tw/opendata/sale11.csv'
df = pd.read_csv(urlread, thousands=',')
df
# Out:
#     口徑(公厘)   用戶數(戶)     用水費(元)
# 0       13   841539  163444948
# 1       20  3628317  726983822
# 2       25  1262063  283133668
# 3       40    48072   89842865
# 4       50     8606   44861873
# 5       75     6276   85131371
# 6      100     3213   92050588
# 7      150     1078   83904527
# 8      200      435   89294800
# 9      250       68   25824699
# 10     300      251  174589436
# 11     350        2     845410
# 12     400       15   13390220
# 13     500       11   18281521
# 14     600        2    3784131
# 15     800        5   18057654
# 16    1000        3   26180460
# 17    1200        2   14822820

# %%
df.columns = ['diameter', 'users', 'fee']

# %%
df
# Out:
#     diameter    users        fee
# 0         13   841539  163444948
# 1         20  3628317  726983822
# 2         25  1262063  283133668
# 3         40    48072   89842865
# 4         50     8606   44861873
# 5         75     6276   85131371
# 6        100     3213   92050588
# 7        150     1078   83904527
# 8        200      435   89294800
# 9        250       68   25824699
# 10       300      251  174589436
# 11       350        2     845410
# 12       400       15   13390220
# 13       500       11   18281521
# 14       600        2    3784131
# 15       800        5   18057654
# 16      1000        3   26180460
# 17      1200        2   14822820

# %%
df.fee.plot()
